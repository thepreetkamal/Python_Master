# %%
#Alcohol consumption data:
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Reading CSV file
drinks = pd.read_csv('C:/Users/Reetinder/Desktop/Python Project/analyse data with python/drinks.csv') 
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# examine the drinks data # DataFrame
type(drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
# print the first 5 rows
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# print the first 10 rows
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
# 5                           4.9       NAm
# 6                           8.3        SA
# 7                           3.8        EU
# 8                          10.4        OC
# 9                           9.7        EU

# %%
# print the last 5 rows
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# summarize all numeric columns
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# column names
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
# data types of each column
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
#number of rows and columns
drinks.shape
# Out:
# (193, 6)

# %%
#complete summary
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 7.6+ KB

# %%
# Print the 'beer_servings' Series (a single column)
drinks.beer_servings
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
#       ...
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, Length: 193, dtype: int64

# %%
# Print two columns
drinks[['country','continent']] 
desired_col = ['country','continent']
drinks[desired_col]
# Out:
#          country continent
# 0    Afghanistan        AS
# 1        Albania        EU
# 2        Algeria        AF
# 3        Andorra        EU
# 4         Angola        AF
# ..           ...       ...
# 188    Venezuela        SA
# 189      Vietnam        AS
# 190        Yemen        AS
# 191       Zambia        AF
# 192     Zimbabwe        AF
#
# [193 rows x 2 columns]

# %%
 # summarize all numeric columns
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# summarize only the 'beer_servings' Series
drinks.beer_servings.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
# Calculate the mean
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
#calculate th max
drinks.beer_servings.max()
# Out:
# 376

# %%
#Calculate the min
drinks.beer_servings.min()
# Out:
# 0

# %%
# Sum & Count functions
drinks.beer_servings.sum()
drinks.beer_servings.count()
float(drinks.beer_servings.sum())/drinks.beer_servings.count()
# Out:
# 106.16062176165804

# %%
# Count the number of occurrences of each 'continent' value
drinks.continent.value_counts()
# Out:
# AF     53
# EU     45
# AS     44
# NAm    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
# Print all columns, but only show rows where the country is in Europe
drinks[drinks.continent=='EU']
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# 60              Finland            263              133             97
# 61               France            127              151            370
# 64              Georgia             52              100            149
# 65              Germany            346              117            175
# 67               Greece            133              112            218
# 75              Hungary            234              215            185
# 76              Iceland            233               61             78
# 81              Ireland            313              118            165
# 83                Italy             85               42            237
# 93               Latvia            281              216             62
# 98            Lithuania            343              244             56
# 99           Luxembourg            236              133            271
# 105               Malta            149              100            120
# 111              Monaco              0                0              0
# 113          Montenegro             31              114            128
# 120         Netherlands            251               88            190
# 126              Norway            169               71            129
# 135              Poland            343              215             56
# 136            Portugal            194               67            339
# 139             Moldova            109              226             18
# 140             Romania            297              122            167
# 147          San Marino              0                0              0
# 151              Serbia            283              131            127
# 155            Slovakia            196              293            116
# 156            Slovenia            270               51            276
# 160               Spain            284              157            112
# 165              Sweden            152               60            186
# 166         Switzerland            185              100            280
# 170           Macedonia            106               27             86
# 180             Ukraine            206              237             45
# 182      United Kingdom            219              126            195
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# 3                            12.4        EU
# 7                             3.8        EU
# 9                             9.7        EU
# 10                            1.3        EU
# 15                           14.4        EU
# 16                           10.5        EU
# 21                            4.6        EU
# 25                           10.3        EU
# 42                           10.2        EU
# 44                            8.2        EU
# 45                           11.8        EU
# 48                           10.4        EU
# 57                            9.5        EU
# 60                           10.0        EU
# 61                           11.8        EU
# 64                            5.4        EU
# 65                           11.3        EU
# 67                            8.3        EU
# 75                           11.3        EU
# 76                            6.6        EU
# 81                           11.4        EU
# 83                            6.5        EU
# 93                           10.5        EU
# 98                           12.9        EU
# 99                           11.4        EU
# 105                           6.6        EU
# 111                           0.0        EU
# 113                           4.9        EU
# 120                           9.4        EU
# 126                           6.7        EU
# 135                          10.9        EU
# 136                          11.0        EU
# 139                           6.3        EU
# 140                          10.4        EU
# 147                           0.0        EU
# 151                           9.6        EU
# 155                          11.4        EU
# 156                          10.6        EU
# 160                          10.0        EU
# 165                           7.2        EU
# 166                          10.2        EU
# 170                           3.9        EU
# 180                           8.9        EU
# 182                          10.4        EU

# %%
# Calculate the average 'beer_servings' for all of Europe
drinks[drinks.continent=='EU'].beer_servings.mean()
# Out:
# 193.77777777777777

# %%
# show European countries with 'wine_servings' greater than 300
drinks[(drinks.continent=='EU') & (drinks.wine_servings > 300)]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
# Show European countries or countries with 'wine_servings' greater than 300
drinks[(drinks.continent=='EU') | (drinks.wine_servings > 300)]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# 60              Finland            263              133             97
# 61               France            127              151            370
# 64              Georgia             52              100            149
# 65              Germany            346              117            175
# 67               Greece            133              112            218
# 75              Hungary            234              215            185
# 76              Iceland            233               61             78
# 81              Ireland            313              118            165
# 83                Italy             85               42            237
# 93               Latvia            281              216             62
# 98            Lithuania            343              244             56
# 99           Luxembourg            236              133            271
# 105               Malta            149              100            120
# 111              Monaco              0                0              0
# 113          Montenegro             31              114            128
# 120         Netherlands            251               88            190
# 126              Norway            169               71            129
# 135              Poland            343              215             56
# 136            Portugal            194               67            339
# 139             Moldova            109              226             18
# 140             Romania            297              122            167
# 147          San Marino              0                0              0
# 151              Serbia            283              131            127
# 155            Slovakia            196              293            116
# 156            Slovenia            270               51            276
# 160               Spain            284              157            112
# 165              Sweden            152               60            186
# 166         Switzerland            185              100            280
# 170           Macedonia            106               27             86
# 180             Ukraine            206              237             45
# 182      United Kingdom            219              126            195
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# 3                            12.4        EU
# 7                             3.8        EU
# 9                             9.7        EU
# 10                            1.3        EU
# 15                           14.4        EU
# 16                           10.5        EU
# 21                            4.6        EU
# 25                           10.3        EU
# 42                           10.2        EU
# 44                            8.2        EU
# 45                           11.8        EU
# 48                           10.4        EU
# 57                            9.5        EU
# 60                           10.0        EU
# 61                           11.8        EU
# 64                            5.4        EU
# 65                           11.3        EU
# 67                            8.3        EU
# 75                           11.3        EU
# 76                            6.6        EU
# 81                           11.4        EU
# 83                            6.5        EU
# 93                           10.5        EU
# 98                           12.9        EU
# 99                           11.4        EU
# 105                           6.6        EU
# 111                           0.0        EU
# 113                           4.9        EU
# 120                           9.4        EU
# 126                           6.7        EU
# 135                          10.9        EU
# 136                          11.0        EU
# 139                           6.3        EU
# 140                          10.4        EU
# 147                           0.0        EU
# 151                           9.6        EU
# 155                          11.4        EU
# 156                          10.6        EU
# 160                          10.0        EU
# 165                           7.2        EU
# 166                          10.2        EU
# 170                           3.9        EU
# 180                           8.9        EU
# 182                          10.4        EU

# %%
# Show countries who have more than the mean beer_servings
drinks[drinks.beer_servings > drinks.beer_servings.mean()]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 3           Andorra            245              138            312
# 4            Angola            217               57             45
# 6         Argentina            193               25            221
# 8         Australia            261               72            212
# 9           Austria            279               75            191
# ..              ...            ...              ...            ...
# 182  United Kingdom            219              126            195
# 184             USA            249              158             84
# 185         Uruguay            115               35            220
# 188       Venezuela            333              100              3
# 189         Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 4                             5.9        AF
# 6                             8.3        SA
# 8                            10.4        OC
# 9                             9.7        EU
# ..                            ...       ...
# 182                          10.4        EU
# 184                           8.7       NAm
# 185                           6.6        SA
# 188                           7.7        SA
# 189                           2.0        AS
#
# [76 rows x 6 columns]

# %%
# 1. What is the maximum number of total litres of pure alcohol?
drinks.total_litres_of_pure_alcohol.max()
# Out:
# 14.4

# %%
# 2. Which country has the maximum number of total litres of pure alcohol?
drinks[drinks.total_litres_of_pure_alcohol == drinks.total_litres_of_pure_alcohol.max()]['country']
# Out:
# 15    Belarus
# Name: country, dtype: object

# %%
# 3. Does Haiti or Belarus consume more servings of spirits?
drinks.spirit_servings[drinks.country=='Haiti'].values > drinks.spirit_servings[drinks.country=='Belarus'].values
# Out:
# array([False])

# %%
# 4. How many countries have more than 300 wine servings OR more than 300 beer servings OR more than 300 spirit servings?
drinks[(drinks.wine_servings > 300) | (drinks.beer_servings > 300) | (drinks.spirit_servings > 300)].country.count()
# Out:
# 18

# %%
# 5. For the countries in the previous question, what is the average total litres of pure alcohol? 
drinks[(drinks.wine_servings > 300) | (drinks.beer_servings > 300) | (drinks.spirit_servings > 300)].mean()
# Out:
# beer_servings                   249.277778
# spirit_servings                 198.000000
# wine_servings                   106.055556
# total_litres_of_pure_alcohol     10.261111
# dtype: float64

# %%
# Determine which 10 countries have the highest 'total_litres_of_pure_alcohol'
drinks.sort_values(by='total_litres_of_pure_alcohol').tail(10)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 99           Luxembourg            236              133            271
# 155            Slovakia            196              293            116
# 81              Ireland            313              118            165
# 141  Russian Federation            247              326             73
# 61               France            127              151            370
# 45       Czech Republic            361              170            134
# 68              Grenada            199              438             28
# 3               Andorra            245              138            312
# 98            Lithuania            343              244             56
# 15              Belarus            142              373             42
#
#      total_litres_of_pure_alcohol continent
# 99                           11.4        EU
# 155                          11.4        EU
# 81                           11.4        EU
# 141                          11.5        AS
# 61                           11.8        EU
# 45                           11.8        EU
# 68                           11.9       NAm
# 3                            12.4        EU
# 98                           12.9        EU
# 15                           14.4        EU

# %%
# Determine which country has the highest value for 'beer_servings'
drinks[drinks.beer_servings==drinks.beer_servings.max()].country
# Out:
# 117    Namibia
# Name: country, dtype: object

# %%
# How many countries in each continent have beer_servings greater than 182? 
drinks[drinks.beer_servings > 182].continent.value_counts()
# Out:
# EU     28
# NAm     9
# SA      4
# OC      4
# AF      4
# AS      1
# Name: continent, dtype: int64

# %%
# add a new column as a function of existing columns (e.g., 'drinks.total_servings')
drinks['total_servings'] = drinks.beer_servings + drinks.spirit_servings + drinks.wine_servings
drinks['alcohol_mL'] = drinks.total_litres_of_pure_alcohol * 1000
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_servings  alcohol_mL
# 0                           0.0        AS               0         0.0
# 1                           4.9        EU             275      4900.0
# 2                           0.7        AF              39       700.0
# 3                          12.4        EU             695     12400.0
# 4                           5.9        AF             319      5900.0

# %%
# for each continent, calculate mean beer servings
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF      61.471698
# AS      37.045455
# EU     193.777778
# NAm    145.434783
# OC      89.687500
# SA     175.083333
# Name: beer_servings, dtype: float64

# %%
# for each continent, calculate mean of all numeric columns
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# NAm           145.434783       165.739130      24.521739
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol  total_servings   alcohol_mL
# continent
# AF                             3.007547       94.075472  3007.547170
# AS                             2.170455      106.954545  2170.454545
# EU                             8.617778      468.555556  8617.777778
# NAm                            5.995652      335.695652  5995.652174
# OC                             3.381250      183.750000  3381.250000
# SA                             6.308333      352.250000  6308.333333

# %%
# for each continent, count number of occurrences
drinks.groupby('continent').continent.count()
drinks.continent.value_counts()
# Out:
# AF     53
# EU     45
# AS     44
# NAm    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
# 1. What is the average number of total litres of pure alcohol for each continent?
drinks.groupby('continent').total_litres_of_pure_alcohol.mean()
# Out:
# continent
# AF     3.007547
# AS     2.170455
# EU     8.617778
# NAm    5.995652
# OC     3.381250
# SA     6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
# 2. For each continent, calculate the mean wine_servings for all countries who have a spirit_servings greater than the overall spirit_servings mean.
drinks[drinks.spirit_servings > drinks.spirit_servings.mean()].groupby('continent').wine_servings.mean()
# Out:
# continent
# AF      30.500000
# AS      11.500000
# EU     143.323529
# NAm     27.750000
# OC      40.500000
# SA      42.000000
# Name: wine_servings, dtype: float64

# %%
# 3. Per continent, for all of the countries that drink more beer servings than the average number of beer servings, what is the average number of wine servings?
drinks[drinks.beer_servings > drinks.beer_servings.mean()].groupby('continent').wine_servings.mean()
# Out:
# continent
# AF      36.500000
# AS      23.750000
# EU     163.485714
# NAm     33.642857
# OC     104.250000
# SA      68.000000
# Name: wine_servings, dtype: float64

# %%
#relationship between wine_serving and continent
sns.catplot(y='wine_servings',data=drinks,x='continent')

# %%
#correlation matrix using heatmap
plt.figure(figsize=(10,10))
sns.heatmap(drinks.corr(),color="k", annot=True)

# %%
g = sns.PairGrid(drinks)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
sns.pairplot(drinks, hue="continent", height=2.5);
