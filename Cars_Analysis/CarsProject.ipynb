# %%
# importing section 
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy as sp

# %%
# using the Csv file 
df = pd.read_csv('C:/Users/Preet/Desktop/Pandas/Python/Corey/cars.csv')  
# Checking the first 5 entries of dataset 
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Finding the missing values 
df.isna().any()   
# Finding if missing values  
df.isnull().any()
# Out:
# symboling            False
# normalized-losses     True
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors          True
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                  True
# stroke                True
# compression-ratio    False
# horsepower            True
# peak-rpm              True
# city-mpg             False
# highway-mpg          False
# price                False
# price-binned         False
# dtype: bool

# %%
# converting mpg to L / 100km 
df['city-mpg'] = 235 / df['city-mpg'] 
df.rename(columns = {'city_mpg': "city-L / 100km"}, inplace = True)   
print(df.columns)   
# checking the data type of each column 
data.dtypes
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'price-binned'],
#       dtype='object')
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# ...

# %%
#Step 5: Here, price is of object type(string), it should be int or float, so we need to change it
df.price.unique() 
  
# Here it contains '?', so we Drop it 
df = df[data.price != '?'] 
  
# checking it again 
df.dtypes
# Out:
# symboling               int64
# normalized-losses      object
# make                   object
# fuel-type              object
# aspiration             object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                   object
# stroke                 object
# compression-ratio     float64
# horsepower             object
# peak-rpm               object
# city-mpg              float64
# highway-mpg             int64
# price                   int32
# price-binned         category
# dtype: object

# %%
data.price.unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '32250', '35550', '36000',
#        '5195', '6095', '6795', '6695', '7395', '10945', '11845', '13645',
#        '15645', '8495', '10595', '10245', '10795', '11245', '18280',
#        '18344', '25552', '28248', '28176', '31600', '34184', '35056',
#        '40960', '45400', '16503', '5389', '6189', '6669', '7689', '9959',
#        '8499', '12629', '14869', '14489', '6989', '8189', '9279', '5499',
#        '7099', '6649', '6849', '7349', '7299', '7799', '7499', '7999',
#        '8249', '8949', '9549', '13499', '14399', '17199', '19699',
# ...

# %%
df = df[df.price != '?']

# %%
#Step 6: Normalizing values by using simple feature scaling method examples(do for the rest) and binning- grouping values
df['length'] = df['length']/df['length'].max()

# %%
df['width'] = df['width']/df['width'].max()

# %%
df['height'] = df['height']/df['height'].max()

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg             float64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df = df[df.price != '?']

# %%
df.dropna(subset=["price"],axis=0,inplace= True)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg             float64
# highway-mpg            int64
# price                  int32
# dtype: object

# %%
df.price.unique()
# Out:
# array([13495, 16500, 13950, 17450, 15250, 17710, 18920, 23875, 16430,
#        16925, 20970, 21105, 24565, 30760, 41315, 36880,  5151,  6295,
#         6575,  5572,  6377,  7957,  6229,  6692,  7609,  8558,  8921,
#        12964,  6479,  6855,  5399,  6529,  7129,  7295,  7895,  9095,
#         8845, 10295, 12945, 10345,  6785, 11048, 32250, 35550, 36000,
#         5195,  6095,  6795,  6695,  7395, 10945, 11845, 13645, 15645,
#         8495, 10595, 10245, 10795, 11245, 18280, 18344, 25552, 28248,
#        28176, 31600, 34184, 35056, 40960, 45400, 16503,  5389,  6189,
#         6669,  7689,  9959,  8499, 12629, 14869, 14489,  6989,  8189,
#         9279,  5499,  7099,  6649,  6849,  7349,  7299,  7799,  7499,
#         7999,  8249,  8949,  9549, 13499, 14399, 17199, 19699, 18399,
#        11900, 13200, 12440, 13860, 15580, 16900, 16695, 17075, 16630,
#        17950, 18150, 12764, 22018, 32528, 34028, 37028,  9295,  9895,
# ...

# %%
df["price"].isna().any()
# Out:
# False

# %%
df.replace("?",np.nan,inplace=True)

# %%
df["price"].isna().any()
# Out:
# True

# %%
df.dropna(subset=["price"],axis=0,inplace= True)

# %%
df["price"].isna().any()
# Out:
# False

# %%
df["price"]=df["price"].astype(int)

# %%
# binning- grouping values 
bins = np.linspace(min(df['price']), max(df['price']), 4)

# %%
group_names = ['Low', 'Medium', 'High'] 
df['price-binned'] = pd.cut(df['price'], bins,  
                              labels = group_names,  
                              include_lowest = True) 
  
print(df['price-binned']) 
plt.hist(df['price-binned']) 
plt.show()
# Out:
# 0         Low
# 1         Low
# 2         Low
# 3         Low
# 4         Low
#         ...
# 200       Low
# 201    Medium
# 202    Medium
# 203    Medium
# 204    Medium
# Name: price-binned, Length: 201, dtype: category
# Categories (3, object): [Low < Medium < High]

# %%
#Step 7: Doing descriptive analysis of data categorical to numerical values.
# categorical to numerical variables 
pd.get_dummies(df['fuel-type']).head() 
  
# descriptive analysis 
# NaN are skipped 
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  201.000000  201.000000  201.000000  201.000000  201.000000
# mean     0.840796   98.797015    0.837102    0.915126    0.899108
# std      1.254802    6.066366    0.059213    0.029187    0.040933
# min     -2.000000   86.600000    0.678039    0.837500    0.799331
# 25%      0.000000   94.500000    0.801538    0.890278    0.869565
# 50%      1.000000   97.000000    0.832292    0.909722    0.904682
# 75%      2.000000  102.400000    0.881788    0.925000    0.928094
# max      3.000000  120.900000    1.000000    1.000000    1.000000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg  \
# count   201.000000   201.000000         201.000000  201.000000   201.000000
# mean   2555.666667   126.875622          10.164279   25.179104    30.686567
# std     517.296727    41.546834           4.004965    6.423220     6.815150
# ...

# %%
#Step 8: Plotting the data according to the price based on engine size.
# examples of box plot 
plt.boxplot(df['price']) 
  
# by using seaborn 
sns.boxplot(x ='drive-wheels', y ='price', data = df) 
  
# Predicting price based on engine size 
# Known on x and predictable on y 
plt.scatter(data['engine-size'], df['price']) 
plt.title('Scatterplot of Enginesize vs Price') 
plt.xlabel('Engine size') 
plt.ylabel('Price') 
plt.grid() 
plt.show()

# %%
#Grouping the data according to wheel, body-style and price.
# Grouping Data 
test = df[['drive-wheels', 'body-style', 'price']] 
data_grp = test.groupby(['drive-wheels', 'body-style'],  
                         as_index = False).mean() 
  
data_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
#Step 10: Using the pivot method and plotting the heatmap according to the data obtained by pivot method
# pivot method 
data_pivot = data_grp.pivot(index = 'drive-wheels', 
                            columns = 'body-style') 
data_pivot 
  
# heatmap for visualizing data 
plt.pcolor(data_pivot, cmap ='RdBu') 
plt.colorbar() 
plt.show()

# %%
#Step 11: Obtaining the final result and showing it in the form of a graph. As the slope is increasing in a positive direction, it is a positive linear relationship.
# Analysis of Variance- ANOVA 
# returns f-test and p-value 
# f-test = variance between sample group means divided by  
# variation within sample group 
# p-value = confidence degree 
data_annova = df[['make', 'price']] 
grouped_annova = data_annova.groupby(['make']) 
annova_results_l = sp.stats.f_oneway( 
                             grouped_annova.get_group('honda')['price'], 
                             grouped_annova.get_group('subaru')['price'] 
                                    ) 
print(annova_results_l) 
  
# strong corealtion between a categorical variable 
# if annova test gives large f-test and small p-value 
  
# Correlation- measures dependency, not causation 
sns.regplot(x ='engine-size', y ='price', data = df) 
plt.ylim(0, )
# Out:
# F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)
# (0.0, 53220.664872164496)

# %%
#correlation between all the columns
df.corr()
# Out:
#                    symboling  wheel-base    length     width    height  \
# symboling           1.000000   -0.535987 -0.365404 -0.242423 -0.550160
# wheel-base         -0.535987    1.000000  0.876024  0.814507  0.590742
# length             -0.365404    0.876024  1.000000  0.857170  0.492063
# width              -0.242423    0.814507  0.857170  1.000000  0.306002
# height             -0.550160    0.590742  0.492063  0.306002  1.000000
# curb-weight        -0.233118    0.782097  0.880665  0.866201  0.307581
# engine-size        -0.110581    0.572027  0.685025  0.729436  0.074694
# compression-ratio  -0.182196    0.250313  0.159733  0.189867  0.259737
# city-mpg           -0.035527   -0.470606 -0.665192 -0.633531 -0.049800
# highway-mpg         0.036233   -0.543304 -0.698142 -0.680635 -0.104812
# price              -0.082391    0.584642  0.690628  0.751265  0.135486
#
#                    curb-weight  engine-size  compression-ratio  city-mpg  \
# ...

# %%
df[["wheel-base","length"]].corr()
# Out:
#             wheel-base    length
# wheel-base    1.000000  0.876024
# length        0.876024  1.000000

# %%
sns.regplot(x="engine-size",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 53282.09884189551)

# %%
df[["engine-size","price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x="highway-mpg",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 48179.62466687658)

# %%
df[["highway-mpg","price"]].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
df.dropna(subset=["peak-rpm"],axis=0,inplace= True)

# %%
df["peak-rpm"].isna().any()
# Out:
# False

# %%
df["peak-rpm"]=df["peak-rpm"].astype(int)

# %%
sns.regplot(x="peak-rpm",y="price",data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
df[["peak-rpm","price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101649
# price    -0.101649  1.000000

# %%
sns.boxplot(x='body-style',y="price",data=df)

# %%
sns.boxplot(x='engine-location',y="price",data=df)

# %%
sns.boxplot(x='drive-wheels',y="price",data=df)

# %%
df["drive-wheels"].value_counts()
# Out:
# fwd    116
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
engineloc= df["engine-location"].value_counts().to_frame()

# %%
engineloc
# Out:
#        engine-location
# front              196
# rear                 3

# %%
engineloc.rename(columns={"engine-location":"value-counts"},inplace=True)

# %%
engineloc.indexname="engine_loc"

# %%
engineloc
# Out:
#        value-counts
# front           196
# rear              3

# %%
df_bodystyle= df[["body-style","price"]]

# %%
group_res= df_bodystyle.groupby(['body-style'],as_index=False).mean()

# %%
group_res
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9958.373134
# 3        sedan  14459.755319
# 4        wagon  12500.166667

# %%
#regression
from scipy import stats
peco, pval= stats.pearsonr(df["wheel-base"],df["price"])

# %%
peco
# Out:
# 0.583796781289392

# %%
pval
# Out:
# 1.4313694393587688e-19

# %%
#as peco< 0.001 so linear relationship is statistically significant.Also, peco(corelation coefficient) 0.58 so relationship is not strong

# %%
#ANOVA ?different drive wheels impact price?
groupsum=df[["drive-wheels","price"]]

# %%
groupsum
# Out:
#     drive-wheels  price
# 0            rwd  13495
# 1            rwd  16500
# 2            rwd  16500
# 3            fwd  13950
# 4            4wd  17450
# ..           ...    ...
# 200          rwd  16845
# 201          rwd  19045
# 202          rwd  21485
# 203          rwd  22470
# 204          rwd  22625
#
# [199 rows x 2 columns]

# %%
groupedannova= groupsum.groupby(["drive-wheels"])

# %%
groupedannova

# %%
annova_results_l = stats.f_oneway( 
                             groupedannova.get_group('fwd')['price'], 
                             groupedannova.get_group('rwd')['price'] ,groupedannova.get_group('4wd')['price'] 
                                    ) 
print(annova_results_l)
# Out:
# F_onewayResult(statistic=66.92990285052078, pvalue=6.995421830700255e-23)

# %%
#since we have large f value it means strong correlation
#also p value of almost zero means statiscally significant

# %%
#residual plot:
plt.figure(figsize=(10,12))
sns.residplot(df["highway-mpg"],df["price"])
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
lr.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# -15700.573979039282

# %%
lr.coef_
# Out:
# array([53.27878556,  4.66217408, 82.22948394, 35.5175845 ])

# %%
Y= lr.predict(Z)

# %%
plt.figure(figsize=(10,12))
ax1= sns.distplot(df["price"],hist= False, color="r",label="Actual value")
sns.distplot(Y,hist= False, color="b",label="Fitted value")
plt.show()

# %%
#polynomial regression
def plotpoly(model,indevar,devar, name):
    xnew= np.linspace(15,55,100)
    ynew= model(xnew)
    plt.plot(indevar,devar,'.',xnew,ynew,'-')
    plt.title("Polynomial Fit")
    ax=plt.gca()
    ax.set_facecolor((0.898,0.898,0.898))
    fig= plt.gcf()
    plt.xlabel(name)
    plt.ylabel('price of car')
    plt.show()
    plt.close()

# %%
x=df['highway-mpg']

# %%
y= df['price']

# %%
f= np.polyfit(x,y,3)

# %%
p= np.poly1d(f)

# %%
plotpoly(p,x,y,'highway-mpg')

# %%
np.polyfit(x,y,3)
# Out:
# array([-1.55294738e+00,  2.04296183e+02, -8.94785018e+03,  1.37721655e+05])

# %%
from sklearn.metrics import mean_squared_error

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lr.fit(X,Y)
# Out:
# LinearRegression()

# %%
lr.score(X,Y) # R squared
# Out:
# 0.4973491560296689

# %%
yhat= lr.predict(X)

# %%
yhat[0:4]
# Out:
# array([16269.37669013, 16269.37669013, 17090.88141229, 13804.86252368])

# %%
mse= mean_squared_error(Y,yhat)

# %%
mse
# Out:
# 31837842.499262147

# %%
#Multi Linear
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
# fit the model 
lr.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lr.score(Z, df['price']))
# Out:
# The R-square is:  0.811469396425812

# %%
Y_predict_multifit = lr.predict(Z)
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11941505.191703448
